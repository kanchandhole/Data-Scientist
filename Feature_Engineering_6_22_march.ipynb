# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchandhole/Data-Scientist/blob/main/Feature_Engineering_6_22_march.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
#
# Ans:![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.
#
# **Ans:**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Interpretation:
#
# ρ = +1 → Perfect positive monotonic relationship
#  As sleep increases, job satisfaction also increases consistently.
#
# ρ ≈ +0.7 to +0.9 → Strong positive relationship
#
# ρ ≈ 0 → No monotonic relationship
#
# ρ ≈ -1 → Strong negative relationship
#
# Conclusion:
#
# This result indicates that more sleep is strongly associated with higher job satisfaction.

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.
#
# **Ans:**
#
# ![image.png](data:image/png;base64,...)
#
# Indicates a strong negative linear relationship
#
# ![image.png](data:image/png;base64,...)
#
# Indicates a strong negative monotonic relationship
#
# ![image.png](data:image/png;base64,...)
#
# 4. Interpretation
#
# Both values are negative
#    As exercise hours increase, BMI decreases
#
# Spearman is slightly stronger
#    Relationship may not be perfectly linear but still consistently decreasing
#
# 5. Conclusion
#
#     There is a strong inverse relationship between exercise and BMI
#     People who exercise more tend to have lower BMI
#
# 6. Key Insight (important for viva/interview)
#
# Use Pearson → when data is linear & normally distributed
#
# Use Spearman → when:
#
# data is skewed
#
# outliers exist
#
# relationship is monotonic but not linear

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.
#
# Ans:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# 3. Expected Result (Realistic Case)
# 𝑟
# ≈
# −
# 0.65
# r≈−0.65
#
# 4. Interpretation
#
# r = -0.65 → Moderate to strong negative correlation
#
#   This means:
#
# As TV watching increases,
#
# Physical activity decreases
#
# 5. Conclusion
#
# There is a negative relationship between television watching and physical activity.
# People who spend more time watching TV tend to be less physically active.
#
# 6. Important Note (for exams)
#
# If r is negative → inverse relationship
#
# If r is positive → direct relationship
#
# If r ≈ 0 → no relationship

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
#
# ![image.png](data:image/png;base64,...)
#
# **Ans:**
#
# ![image.png](data:image/png;base64,...)
#
# Step 4: Interpretation
#
# r = 0.76 → Moderately strong positive relationship
#
#  This suggests:
#
# As age increases, preference tends to shift toward higher-coded drinks (Pepsi → Mountain Dew)
#
# Step 5: Important Note (VERY IMPORTANT for exams ⚠️)
#
# Pearson is not fully appropriate here because:
#
# Preference is categorical (nominal), not numerical
#
# Better methods:
#
# Chi-square test
#
# Spearman (if ranked meaningfully)
#
# Final Conclusion
#
#  There appears to be a moderate relationship between age and drink preference,
# but results should be interpreted carefully due to categorical data.

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
#
# **Ans:**
#
# ![image.png](data:image/png;base64,...)
#
# 3. Expected Result (Practical Scenario)
# 𝑟
# ≈
# +
# 0.85
# r≈+0.85
# 4. Interpretation
#
# r = +0.85 → Strong positive correlation
#
#   Meaning:
#
# More sales calls per day → More sales per week
#
# 5. Conclusion
#
# There is a strong positive relationship between:
#
# effort (calls made)
#
# outcome (sales achieved)
#
#  This suggests that increasing calls can significantly improve sales performance.
#
# 6. Key Insight (for exams/interview)
#
# High positive r → strong direct relationship
#
# Helps in:
#
# performance analysis
#
# business decision-making
#
# sales strategy optimization
