# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchandhole/Data-Scientist/blob/main/Exploratory_Data_analysis_25_march_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Flight Price:

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-11c8026a-1ba2-4b38-904d-49cd025b28b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11c8026a-1ba2-4b38-904d-49cd025b28b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Q1.** Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?
#
# **Ans:** Datasets have 10683 rows and 11 columns

# %%
df = pd.read_excel('flight_price.xlsx')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.size
# Out:
# 117513

# %% [markdown]
# **Q2.** What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.
#
# **Ans:**

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# **Q3.** What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].min()
# Out:
# 1759

# %%
df['Price'].max()
# Out:
# 79512

# %%
Range = df['Price'].max() -df['Price'].min()
Range
# Out:
# 77753

# %% [markdown]
# **Q4.** How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
avg_price = df.groupby('Airline')['Price'].mean()

# %%
avg_price
# Out:
# Airline
# Air Asia                              5590.260188
# Air India                             9611.210616
# GoAir                                 5861.056701
# IndiGo                                5673.682903
# Jet Airways                          11643.923357
# Jet Airways Business                 58358.666667
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# SpiceJet                              4338.284841
# Trujet                                4140.000000
# Vistara                               7796.348643
# Vistara Premium economy               8962.333333
# Name: Price, dtype: float64

# %%
for airline, price in avg_price.items():
    print(f"{airline} → ₹{int(price):,}")
# Out:
# Air Asia → ₹5,590
# Air India → ₹9,611
# GoAir → ₹5,861
# IndiGo → ₹5,673
# Jet Airways → ₹11,643
# Jet Airways Business → ₹58,358
# Multiple carriers → ₹10,902
# Multiple carriers Premium economy → ₹11,418
# SpiceJet → ₹4,338
# Trujet → ₹4,140
# Vistara → ₹7,796
# Vistara Premium economy → ₹8,962

# %% [markdown]
# **Q7.** You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
#
# **Ans:**
#
# 1. Features to Analyze for Price Trends
#
# To identify trends in flight prices, I would analyze the following features:
#
#  1. Date of Journey
# Extract:
#
# * Month
#
# * Day of week
#
# * Helps identify seasonal trends (peak vs off-season)
#
# 2. Airline
#
# * Compare pricing across airlines
#
# Identify:
#
#  * Budget vs premium pricing trends
#
# 3. Total Stops
#
# * Non-stop vs 1-stop vs 2-stop
#
# * Trend:
#
# More stops → usually lower price
#
# 4. Duration
#
# * Longer flights may cost more
# * Helps identify price vs travel time relationship
#
# 5. Source & Destination
#
# * Some routes are more expensive
#
# Example:
# Metro cities → higher demand → higher price
#
# 6. Departure & Arrival Time
#
# * Early morning / late night flights often cheaper
#
# * Peak hours more expensive
#
# 2. Trends to Identify
#
# From these features, I would look for:
#
# * Seasonal price increase (peak months)
#
# * Airline-wise pricing differences
#
# * Stops vs Price relationship
#
# * Duration vs Price trend
#
# * Route-based pricing differences

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#Line Chart (Time Trends)
#Price vs Month
# Convert date column
df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"], format="%d/%m/%Y")

# Extract month
df["Journey_Month"] = df["Date_of_Journey"].dt.month

# Create monthly_price (THIS WAS MISSING)
monthly_price = df.groupby("Journey_Month")["Price"].mean()

# Now plot
plt.figure()
monthly_price.plot(kind="line")
plt.title("Average Flight Price by Month")
plt.xlabel("Month")
plt.ylabel("Price")
plt.show()

# %%
#Airline vs Average Price
#Stops vs Price

df.groupby("Airline")["Price"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Airline'>

# %%
#. Boxplot (Distribution & Outliers)
#Price distribution across airlines
import matplotlib.pyplot as plt
plt.boxplot(df["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x780c539832c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x780c5381f020>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x780c5397ade0>],
#  'medians': [<matplotlib.lines.Line2D at 0x780c538201a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x780c53820470>],
#  'means': []}

# %%
#Scatter Plot (Relationship)
#Duration vs Price
plt.scatter(df["Duration"], df["Price"])

# %%
#Heatmap (Advanced Insight)
#Correlation between features
import seaborn as sns
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
plt.figure()
sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# To analyze trends in flight prices, I would examine features such as Date of Journey, Airline, Total Stops, Duration, Source, and Destination. These features help identify patterns such as seasonal demand, airline pricing strategies, and the relationship between flight duration and ticket price.
#
# To present the findings, I would use various visualizations including line charts to show price trends over time, bar charts for airline and stop-wise comparisons, scatter plots to analyze relationships between duration and price, and boxplots to detect outliers. These visual tools provide clear insights into pricing patterns and help the team make data-driven decisions.

# %% [markdown]
# **Q8.** You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?
#
# **Ans:**
#
# 1. Key Features Affecting Flight Prices
#
# I would analyze the following features:
#
# 1. Airline
#
# * Different airlines have different pricing strategies
#
# * Premium airlines → higher fares
#
# 2. Total Stops
#
# * Non-stop flights → more expensive
#
# * More stops → cheaper
#
# 3. Duration
#
# * Longer duration flights may cost more
#
# * Indicates route complexity
#
# 4. Date of Journey
#
# Extract:
#
# * Month (seasonality)
#
# * Day (weekday vs weekend)
#
# * Peak seasons → higher prices
#
# 5. Source & Destination
#
# * Popular routes → higher demand → higher prices
#
# 6. Departure & Arrival Time
#
# * Peak hours → expensive
#
# * Late night / early morning → cheaper
#
# 7. Days Left for Journey (if available)
#
# Last-minute bookings → higher prices

# %%
#Groupby Analysis
df.groupby("Airline")["Price"].mean()
df.groupby("Total_Stops")["Price"].mean()
df.groupby("Journey_Month")["Price"].mean()
# Out:
# Journey_Month
# 3    10673.205580
# 4     5770.847081
# 5     9127.247548
# 6     8828.796134
# Name: Price, dtype: float64

# %%
#Relationship Analysis
# Duration vs Price
plt.scatter(df["Duration"], df["Price"])

# %%
#Distribution Analysis
# Boxplot for outliers
plt.boxplot(df["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x780c52bd0e60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x780c52d16360>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x780c52ba9bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x780c52d146b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x780c52bfdd30>],
#  'means': []}

# %%
#Feature Importance
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor

# Load data
df = pd.read_excel("flight_price.xlsx")

# Create encoded copy
df_encoded = df.copy()

# Encode categorical columns
le = LabelEncoder()

for col in df_encoded.select_dtypes(include='object').columns:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# Split features and target
X = df_encoded.drop("Price", axis=1)
y = df_encoded["Price"]

# Train model
model = RandomForestRegressor()
model.fit(X, y)

# Feature importance
importances = model.feature_importances_

# Display results
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

print(feature_importance)
# Out:
#            Feature  Importance
# 8      Total_Stops    0.423578
# 1  Date_of_Journey    0.187677
# 0          Airline    0.166995
# 4            Route    0.049315
# 6     Arrival_Time    0.048133
# 7         Duration    0.043450
# 5         Dep_Time    0.033513
# 9  Additional_Info    0.032959
# 2           Source    0.008777
# 3      Destination    0.005602

# %% [markdown]
# ##Google Playstore:
