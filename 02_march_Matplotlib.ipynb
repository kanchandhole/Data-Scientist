# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchandhole/Data-Scientist/blob/main/02_march_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1:** What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
# **Ans:**
#
# ✅ What is Matplotlib?
#
# Matplotlib is a Python data visualization library used to create static, animated, and interactive plots.
#
# ✅ Why is it used?
#
# To visualize data easily
#
# To analyze trends and patterns
#
# To create publication-quality graphs
#
# Works well with NumPy and Pandas
#
# ✅ Five plots using pyplot
#
# Line plot
#
# Scatter plot
#
# Bar plot
#
# Histogram
#
# Box plot

# %% [markdown]
# **Q2:** What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.
#
# **Ans:** ✅ Scatter Plot
#
# A scatter plot shows the relationship between two numerical variables using dots.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# **Q3:** Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
# **Ans:**
#
# ✅ Purpose of subplot()
#
# Used to draw multiple plots in a single figure
#
# Helps in comparison of data

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])

plt.subplot(2, 2, 1)
plt.plot(x, [0, 100, 200, 300, 400, 500])
plt.title("Line 1")

plt.subplot(2, 2, 2)
plt.plot(x, [50, 20, 40, 20, 60, 70])
plt.title("Line 2")

plt.subplot(2, 2, 3)
plt.plot(x, [10, 20, 30, 40, 50, 60])
plt.title("Line 3")

plt.subplot(2, 2, 4)
plt.plot(x, [200, 350, 250, 550, 450, 150])
plt.title("Line 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Q4:** What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
#
# **Ans:**
#
# ✅ Bar Plot
#
# A bar plot represents categorical data using rectangular bars.
#
# ✅ Why used?
#
# To compare values across categories
#
# Easy to interpret

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical bar plot
plt.bar(company, profit)
plt.title("Company Profit")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

# Horizontal bar plot
plt.barh(company, profit)
plt.title("Company Profit (Horizontal)")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# **Q5:** What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)
#
# **Ans:**
#
# ✅ Box Plot
#
# A box plot shows:
#
# Minimum
#
# Maximum
#
# Median
#
# Quartiles
#
# Outliers
#
# ✅ Why used?
#
# To analyze data distribution
#
# To detect outliers

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2])
plt.title("Box Plot Example")
plt.show()
