# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchandhole/Data-Scientist/blob/main/06_feb_AssQ_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1.**Create a function which will take a list as an argument and return the product of all the numbers
# after creating a flat list.
# Use the below-given list as an argument for your function.
# list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34), {1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,
# 22, 61, 34)}, [56, 'data science'], 'Machine Learning']
# Note: you must extract numeric keys and values of the dictionary also.

# %%
def product_of_numbers(data):
    flat_list = []

    def flatten(item):
        # If item is dictionary: take numeric keys + numeric values
        if isinstance(item, dict):
            for k, v in item.items():
                if isinstance(k, (int, float)):
                    flat_list.append(k)
                flatten(v)

        # If item is iterable (list, tuple, set)
        elif isinstance(item, (list, tuple, set)):
            for i in item:
                flatten(i)

        # Keep only numeric values (ignore bool because bool is a subclass of int)
        else:
            if isinstance(item, (int, float)) and not isinstance(item, bool):
                flat_list.append(item)

    flatten(data)

    # Calculate product
    product = 1
    for num in flat_list:
        product *= num

    return product


# Given list
list1 = [
    1,2,3,4,
    [44,55,66, True],
    False,
    (34,56,78,89,34),
    {1,2,3,3,2,1},
    {1:34, "key2":[55,67,78,89], 4:(45,22,61,34)},
    [56, 'data science'],
    'Machine Learning'
]

result = product_of_numbers(list1)
result
# Out:
# 4134711838987085478833841242112000

# %% [markdown]
# **Q2.** Write a python program for encrypting a message sent to you by your friend. The logic of encryption
# should be such that, for a the output should be z. For b, the output should be y. For c, the output should
# be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation
# marks unchanged.
# Input Sentence: I want to become a Data Scientist.
# Encrypt the above input sentence using the program you just created.
# Note: Convert the given input sentence into lowercase before encrypting. The final output should be
# lowercase.

# %%
def encrypt_message(text):
    text = text.lower()
    encrypted = ""

    for ch in text:
        if ch == " ":
            encrypted += "$"
        elif ch.isalpha():
            encrypted += chr(219 - ord(ch))   # reverse alphabet trick
        else:
            encrypted += ch   # keep punctuation unchanged

    return encrypted


sentence = "I want to become a Data Scientist."
encrypted_text = encrypt_message(sentence)
encrypted_text
# Out:
# 'r$dzmg$gl$yvxlnv$z$wzgz$hxrvmgrhg.'
