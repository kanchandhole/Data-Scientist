# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchandhole/Data-Scientist/blob/main/10th_march_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q1:** What is Estimation Statistics? Explain point estimate and interval estimate.
#
# **Ans:**
# Estimation statistics is used to estimate population parameters using sample data.
#
# * Point Estimate: A single value used to estimate a population parameter
# Example: Sample mean estimates population mean
#
# * Interval Estimate: A range of values within which the population parameter lies with a certain confidence level
# Example: 95% confidence interval

# %% [markdown]
# **Q2.** Write a Python function to estimate the population mean using a sample mean and standard
# deviation.
#
# **Ans:**

# %%
import math

def estimate_mean(sample_mean, sample_std, n, z=1.96):
    margin = z * (sample_std / math.sqrt(n))
    return (sample_mean - margin, sample_mean + margin)

estimate_mean(500, 50, 50)
# Out:
# (486.1407070887437, 513.8592929112564)

# %% [markdown]
# **Q3:** What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
#
# **Ans:** Hypothesis testing is a statistical method to make decisions about population parameters using sample data.
# It helps determine whether observed results are statistically significant.

# %% [markdown]
# **Q4.** Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.
#
# **ans:**
# * Null Hypothesis (H₀): Average weight of male students ≤ female students
#
# * Alternative Hypothesis (H₁): Average weight of male students > female students

# %% [markdown]
# **Q5.** Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.
#
# **Ans:**

# %%
from scipy.stats import ttest_ind

sample1 = [70, 72, 68, 75, 71]
sample2 = [65, 66, 64, 63, 67]

t_stat, p_val = ttest_ind(sample1, sample2)
print(t_stat, p_val)
# Out:
# 4.570700640801813 0.001824111410905962

# %% [markdown]
# **Q6:** What is a null and alternative hypothesis? Give some examples.
#
# **Ans:**
#
# * Null (H₀): No effect / no difference
#
# * Alternative (H₁): There is an effect / difference
#
# Example:
#
# H₀: μ = 50
#
# H₁: μ ≠ 50

# %% [markdown]
# **Q7:** Write down the steps involved in hypothesis testing.
#
# **Ans:**
#
# 1. State hypotheses
#
# 2. Choose significance level (α)
#
# 3. Select test statistic
#
# 4. Compute p-value
#
# 5.  decision
#
# 6. Draw conclusion

# %% [markdown]
# **Q8.** Define p-value and explain its significance in hypothesis testing.
#
# **Ans:**  The p-value is the probability of observing the data assuming the null hypothesis is true.
#
# If p ≤ α, reject H₀
#
# If p > α, fail to reject H₀

# %% [markdown]
# **Q9.** Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.
#
# **Ans:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

x = np.linspace(-4, 4, 100)
y = t.pdf(x, df=10)

plt.plot(x, y)
plt.title("Student's t Distribution (df=10)")
plt.xlabel("x")
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# **Q10.** Write a Python program to calculate the two-sample t-test for independent samples, given two
# random samples of equal size and a null hypothesis that the population means are equal.
#
# **Ans:**

# %%
from scipy.stats import ttest_ind
import numpy as np

a = np.random.rand(30)
b = np.random.rand(30)

t_stat, p_val = ttest_ind(a, b)
print(t_stat, p_val)
# Out:
# -0.2505391599162 0.8030558170128967

# %% [markdown]
# **Q11:** What is Student’s t distribution? When to use the t-Distribution.
#
# **Ans:** Student’s t-distribution is a probability distribution used to estimate population parameters when the sample size is small and the population standard deviation is unknown. It is similar to the normal distribution but has heavier tails, making it more reliable for small samples.
#
# Used when:
#
# * Sample size is small
#
# * Population standard deviation is unknown
#
# * Data is approximately normal

# %% [markdown]
# **Q12:** What is t-statistic? State the formula for t-statistic.
#
# **Ans:** The t-statistic is a value used in hypothesis testing to measure how far the sample mean is from the population mean, relative to the variability in the data. It helps determine whether the difference observed is statistically significant.
#
# t=s/n
# ​xˉ−μ​

# %% [markdown]
# **Q13.** A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.
#
# **ans:**
#
# Given:
#
# * Sample mean ((\bar{x})) = 500
# * Sample standard deviation (s) = 50
# * Sample size (n) = 50
# * Confidence level = 95% → (z = 1.96)
#
# **Formula for Confidence Interval:**
# [
# \bar{x} \pm z \times \frac{s}{\sqrt{n}}
# ]
#
# **Calculation:**
# [
# \frac{50}{\sqrt{50}} = 7.07
# ]
# [
# \text{Margin of Error} = 1.96 \times 7.07 \approx 13.86
# ]
#
# **95% Confidence Interval:**
# [
# 500 \pm 13.86
# ]
#
# **Final Answer:**
# The population mean revenue lies between **$486.14 and $513.86** with 95% confidence.

# %% [markdown]
# **Q14.** A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
#
# **Ans:**
#
# **Given:**
#
# * Hypothesized mean decrease ((\mu_0)) = 10 mmHg
# * Sample mean ((\bar{x})) = 8 mmHg
# * Sample standard deviation (s) = 3 mmHg
# * Sample size (n) = 100
# * Significance level ((\alpha)) = 0.05
#
# ---
#
# ### **Step 1: State the hypotheses**
#
# * **Null hypothesis (H₀):** (\mu = 10)
# * **Alternative hypothesis (H₁):** (\mu \neq 10)
#
# ---
#
# ### **Step 2: Calculate the test statistic**
#
# [
# t = \frac{\bar{x} - \mu_0}{s / \sqrt{n}}
# = \frac{8 - 10}{3 / \sqrt{100}}
# = \frac{-2}{0.3}
# = -6.67
# ]
#
# ---
#
# ### **Step 3: Critical value / p-value**
#
# For a two-tailed test at (\alpha = 0.05), the critical value is approximately **±1.96**.
#
# ---
#
# ### **Step 4: Decision**
#
# Since (|t| = 6.67 > 1.96), we **reject the null hypothesis**.
#
# ---
#
# ### **Conclusion**
#
# There is **significant statistical evidence** at the 0.05 level to conclude that the new drug **does not decrease blood pressure by 10 mmHg**.

# %% [markdown]
# **Q15.** An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.
#
# **Ans:**
#
# **Given:**
#
# * Population mean ((\mu_0)) = 5 pounds
# * Population standard deviation ((\sigma)) = 0.5 pounds
# * Sample size (n) = 25
# * Sample mean ((\bar{x})) = 4.8 pounds
# * Significance level ((\alpha)) = 0.01
#
# ---
#
# ### **Step 1: State the hypotheses**
#
# * **Null hypothesis (H₀):** (\mu = 5)
# * **Alternative hypothesis (H₁):** (\mu < 5) *(left-tailed test)*
#
# ---
#
# ### **Step 2: Calculate the test statistic**
#
# [
# z = \frac{\bar{x} - \mu_0}{\sigma / \sqrt{n}}
# = \frac{4.8 - 5}{0.5 / \sqrt{25}}
# = \frac{-0.2}{0.1}
# = -2.0
# ]
#
# ---
#
# ### **Step 3: Critical value**
#
# For a **left-tailed test** at (\alpha = 0.01),
# Critical value (z = -2.33)
#
# ---
#
# ### **Step 4: Decision**
#
# Since **−2.0 > −2.33**, we **fail to reject the null hypothesis**.
#
# ---
#
# ### **Conclusion**
#
# At the 0.01 significance level, there is **not enough statistical evidence** to conclude that the true mean weight of the products is **less than 5 pounds**.

# %% [markdown]
# **Q16.** Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.
#
# **Ans:**
#
# **Given:**
#
# * Group 1: (n_1 = 30), (\bar{x}_1 = 80), (s_1 = 10)
# * Group 2: (n_2 = 40), (\bar{x}_2 = 75), (s_2 = 8)
# * Significance level: (\alpha = 0.01)
#
# ---
#
# ### **Step 1: State the hypotheses**
#
# * **Null hypothesis (H₀):** (\mu_1 = \mu_2)
# * **Alternative hypothesis (H₁):** (\mu_1 \neq \mu_2)
#
# ---
#
# ### **Step 2: Calculate the test statistic**
#
# [
# t = \frac{\bar{x}_1 - \bar{x}_2}{\sqrt{\frac{s_1^2}{n_1} + \frac{s_2^2}{n_2}}}
# ]
#
# [
# t = \frac{80 - 75}{\sqrt{\frac{10^2}{30} + \frac{8^2}{40}}}
# = \frac{5}{\sqrt{3.33 + 1.6}}
# = \frac{5}{2.22}
# \approx 2.25
# ]
#
# ---
#
# ### **Step 3: Critical value**
#
# For a **two-tailed test** at (\alpha = 0.01), the critical t-value is approximately **±2.58**.
#
# ---
#
# ### **Step 4: Decision**
#
# Since (|t| = 2.25 < 2.58), we **fail to reject the null hypothesis**.
#
# ---
#
# ### **Conclusion**
#
# At the 0.01 significance level, there is **no statistically significant difference** between the population mean scores of the two groups.

# %% [markdown]
# **Q17.** A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.
#
# **Ans:**
#
# **Given:**
#
# * Sample mean ((\bar{x})) = 4
# * Sample standard deviation (s) = 1.5
# * Sample size (n) = 50
# * Confidence level = 99% → (z = 2.576)
#
# ---
#
# ### **Formula for Confidence Interval**
#
# [
# \bar{x} \pm z \times \frac{s}{\sqrt{n}}
# ]
#
# ---
#
# ### **Calculation**
#
# [
# \frac{1.5}{\sqrt{50}} \approx 0.212
# ]
#
# [
# \text{Margin of Error} = 2.576 \times 0.212 \approx 0.55
# ]
#
# ---
#
# ### **99% Confidence Interval**
#
# [
# 4 \pm 0.55
# ]
#
# ---
#
# ### **Final Answer**
#
# The population mean number of ads watched lies between **3.45 and 4.55** with **99% confidence**.
